# %%
import numpy as np
import pandas as pd

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 46.6 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import os
from nltk.tokenize import sent_tokenize
from gensim.utils import simple_preprocess

story = []

for filename in os.listdir('/content'):
    if filename.endswith('.txt'):

        with open(os.path.join('/content', filename), 'r', encoding='latin-1') as f:
            corpus = f.read()

        raw_sent = sent_tokenize(corpus)

        for sent in raw_sent:
            story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 145020

# %%
model=gensim.models.Word2Vec(
    window=10,
    min_count=2,
    workers=4,
)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (6571491, 8628190)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.8081095218658447),
#  ('targaryen', 0.7306329607963562),
#  ('unburnt', 0.7218188643455505),
#  ('queen', 0.7207208871841431),
#  ('margaery', 0.7085699439048767),
#  ('westeros', 0.7048530578613281),
#  ('princess', 0.7012743353843689),
#  ('myrcella', 0.6767503023147583),
#  ('dorne', 0.6650485396385193),
#  ('elia', 0.6596789360046387)]

# %%
model.wv.doesnt_match(['jon','arya','robb','sansa'])
# Out:
# 'jon'

# %%
model.wv.similarity('arya','sansa')
# Out:
# np.float32(0.87064147)

# %%
model.wv.get_normed_vectors().shape
# Out:
# (17453, 100)

# %%
y=model.wv.index_to_key

# %%
len(y)
# Out:
# 17453

# %%
y
# Out:
# ['the',
#  'and',
#  'to',
#  'of',
#  'he',
#  'his',
#  'was',
#  'you',
#  'her',
#  'in',
#  'it',
#  'had',
#  'that',
#  'she',
#  'as',
#  'with',
#  'him',
#  'not',
#  'but',
#  'for',
#  'they',
#  'is',
#  'at',
#  'on',
#  'said',
#  'my',
#  'have',
#  'be',
#  'lord',
#  'them',
#  'no',
#  'from',
#  'would',
#  'were',
#  'me',
#  'your',
#  'one',
#  'all',
#  'when',
#  'will',
#  'ser',
#  'if',
#  'so',
#  'their',
#  'we',
#  'could',
#  'are',
#  'man',
#  'there',
#  'this',
#  'up',
#  'been',
#  'what',
#  'did',
#  'by',
#  'king',
#  'do',
#  'men',
#  'back',
#  'out',
#  'more',
#  'or',
#  'who',
#  'down',
#  'well',
#  'than',
#  'only',
#  'like',
#  'jon',
#  'some',
#  'father',
#  'old',
#  'hand',
#  'even',
#  'too',
#  'tyrion',
#  'before',
#  'never',
#  'an',
#  'off',
#  'know',
#  'see',
#  'into',
#  'made',
#  'now',
#  'eyes',
#  'black',
#  'told',
#  'lady',
#  'thought',
#  'time',
#  'then',
#  'how',
#  'long',
#  'has',
#  'can',
#  'might',
#  'us',
#  'come',
#  'where',
#  'here',
#  'through',
#  'face',
#  'still',
#  'head',
#  'red',
#  'll',
#  'way',
#  'boy',
#  'page',
#  'must',
#  'once',
#  'queen',
#  'good',
#  'two',
#  'brother',
#  'night',
#  'over',
#  'little',
#  'about',
#  'took',
#  'other',
#  'came',
#  'though',
#  'again',
#  'say',
#  'three',
#  'should',
#  'away',
#  'dead',
#  'son',
#  'own',
#  'blood',
#  'am',
#  'take',
#  'go',
#  'half',
#  'make',
#  'arya',
#  'saw',
#  'day',
#  'white',
#  'jaime',
#  'first',
#  'himself',
#  'our',
#  'look',
#  'want',
#  'after',
#  'much',
#  'enough',
#  'sword',
#  'tell',
#  'girl',
#  'bran',
#  'great',
#  'its',
#  'looked',
#  'left',
#  'knew',
#  'asked',
#  'gave',
#  'maester',
#  'called',
#  'wall',
#  'every',
#  'heard',
#  'sansa',
#  'let',
#  'yet',
#  'went',
#  'turned',
#  'dany',
#  'why',
#  'need',
#  'behind',
#  'around',
#  'just',
#  'woman',
#  'another',
#  'snow',
#  'beneath',
#  'across',
#  'knight',
#  'keep',
#  'grace',
#  'found',
#  'gold',
#  'any',
#  'last',
#  'cersei',
#  'castle',
#  'those',
#  'stark',
#  'gods',
#  'think',
#  'hair',
#  'many',
#  'feet',
#  'against',
#  'hands',
#  'stannis',
#  'mother',
#  'catelyn',
#  'robert',
#  'seemed',
#  'prince',
#  'may',
#  'ever',
#  'robb',
#  'done',
#  'don',
#  'find',
#  'lannister',
#  're',
#  'hear',
#  'name',
#  'grey',
#  'horse',
#  'high',
#  'put',
#  'wine',
#  'stone',
#  'hard',
#  'water',
#  'upon',
#  'fire',
#  'iron',
#  'until',
#  'these',
#  'voice',
#  'gone',
#  'give',
#  'sam',
#  'better',
#  'seen',
#  'shall',
#  'ned',
#  'always',
#  'years',
#  'between',
#  'dark',
#  'place',
#  'small',
#  'cold',
#  'winterfell',
#  'most',
#  'hundred',
#  'stood',
#  'end',
#  'sister',
#  'words',
#  'sea',
#  'right',
#  'nothing',
#  'walls',
#  'fingers',
#  'same',
#  'house',
#  'cloak',
#  'young',
#  'beside',
#  'does',
#  'get',
#  'seven',
#  'mouth',
#  'watch',
#  'door',
#  'joffrey',
#  'green',
#  'big',
#  'under',
#  'few',
#  'sent',
#  'perhaps',
#  'almost',
#  'such',
#  'wanted',
#  'true',
#  'daughter',
#  'leave',
#  'while',
#  'wind',
#  'city',
#  'light',
#  'arms',
#  'children',
#  'herself',
#  'sweet',
#  'others',
#  'lost',
#  'theon',
#  'each',
#  'felt',
#  'side',
#  'yes',
#  'brothers',
#  'best',
#  'very',
#  'die',
#  'brought',
#  'soon',
#  'died',
#  'far',
#  'north',
#  'fear',
#  'child',
#  'along',
#  'brienne',
#  'word',
#  'both',
#  'taken',
#  'battle',
#  'help',
#  'new',
#  'tywin',
#  'lords',
#  'davos',
#  'something',
#  've',
#  'wife',
#  'mean',
#  'hall',
#  'rest',
#  'kill',
#  'steel',
#  'strong',
#  'began',
#  'sound',
#  'won',
#  'dragon',
#  'past',
#  'life',
#  'tower',
#  'killed',
#  'arm',
#  'tried',
#  'free',
#  'sons',
#  'thing',
#  'bear',
#  'days',
#  'bloody',
#  'heart',
#  'pale',
#  'love',
#  'moment',
#  'sat',
#  'bring',
#  'bed',
#  'close',
#  'knights',
#  'cut',
#  'wolf',
#  'death',
#  'smile',
#  'horses',
#  'inside',
#  'four',
#  'brown',
#  'dragons',
#  'hot',
#  'silver',
#  'part',
#  'bastard',
#  'open',
#  'nor',
#  'thousand',
#  'landing',
#  'uncle',
#  'above',
#  'going',
#  'blue',
#  'captain',
#  'air',
#  'please',
#  'laughed',
#  'river',
#  'sun',
#  'rose',
#  'fell',
#  'war',
#  'golden',
#  'sleep',
#  'swords',
#  'without',
#  'renly',
#  'speak',
#  'full',
#  'certain',
#  'fool',
#  'beyond',
#  'feel',
#  'send',
#  'fight',
#  'got',
#  'tongue',
#  'rode',
#  'set',
#  'thick',
#  'throat',
#  'world',
#  'deep',
#  'legs',
#  'call',
#  'honor',
#  'trees',
#  'rock',
#  'tall',
#  'table',
#  'pulled',
#  'mormont',
#  'women',
#  'broken',
#  'steps',
#  'things',
#  'next',
#  'hodor',
#  'heavy',
#  'burned',
#  'oh',
#  'toward',
#  'together',
#  'given',
#  'skin',
#  'since',
#  'dwarf',
#  'moved',
#  'smiled',
#  'alone',
#  'storm',
#  'raised',
#  'ride',
#  'ask',
#  'eye',
#  'hope',
#  'reached',
#  'soft',
#  'frey',
#  'second',
#  'remember',
#  'remembered',
#  'someone',
#  'coming',
#  'hold',
#  'meant',
#  'cannot',
#  'morning',
#  'ten',
#  'teeth',
#  'else',
#  'throne',
#  'command',
#  'fat',
#  'which',
#  'truth',
#  'walder',
#  'commander',
#  'ground',
#  'doubt',
#  'jorah',
#  'cup',
#  'outside',
#  'known',
#  'wore',
#  'ran',
#  'gate',
#  'held',
#  'room',
#  'closed',
#  'home',
#  'matter',
#  'south',
#  'wood',
#  'sky',
#  'people',
#  'dozen',
#  'wed',
#  'neck',
#  'food',
#  'riverrun',
#  'near',
#  'instead',
#  'turn',
#  'talk',
#  'none',
#  'ships',
#  'tyrell',
#  'below',
#  'moon',
#  'bolton',
#  'lips',
#  'shadow',
#  'summer',
#  'watched',
#  'times',
#  'leather',
#  'varys',
#  'shoulder',
#  'septon',
#  'warm',
#  'caught',
#  'believe',
#  'least',
#  'guards',
#  'answer',
#  'blade',
#  'god',
#  'wondered',
#  'ice',
#  'barristan',
#  'shield',
#  'opened',
#  'mine',
#  'armor',
#  'safe',
#  'six',
#  'kept',
#  'wish',
#  'return',
#  'tommen',
#  'used',
#  'smell',
#  'less',
#  'being',
#  'foot',
#  'squire',
#  'floor',
#  'eddard',
#  'empty',
#  'run',
#  'followed',
#  'serve',
#  'friends',
#  'boys',
#  'beard',
#  'wedding',
#  'cloaks',
#  'baratheon',
#  'wrong',
#  'eat',
#  'daenerys',
#  'ghost',
#  'hound',
#  'sight',
#  'five',
#  'flesh',
#  'ship',
#  'strength',
#  'nose',
#  'returned',
#  'bones',
#  'crown',
#  'yellow',
#  'chest',
#  'covered',
#  'says',
#  'commanded',
#  'petyr',
#  'aemon',
#  'sometimes',
#  'filled',
#  'friend',
#  'led',
#  'yours',
#  'aye',
#  'common',
#  'fighting',
#  'flames',
#  'show',
#  'spoke',
#  'asha',
#  'huge',
#  'aside',
#  'lysa',
#  'crow',
#  'belly',
#  'master',
#  'breath',
#  'seem',
#  'yard',
#  'gates',
#  'waiting',
#  'within',
#  'looking',
#  'wooden',
#  'wet',
#  'realm',
#  'thin',
#  'work',
#  'promised',
#  'use',
#  'bad',
#  'tree',
#  'husband',
#  'grew',
#  'later',
#  'onto',
#  'wildlings',
#  'loved',
#  'greyjoy',
#  'girls',
#  'afraid',
#  'shoulders',
#  'rain',
#  'walked',
#  'shouted',
#  'maid',
#  'mance',
#  'remained',
#  'guard',
#  'late',
#  'meereen',
#  'fall',
#  'littlefinger',
#  'liked',
#  'margaery',
#  'dog',
#  'year',
#  'hurt',
#  'passed',
#  'balon',
#  'taste',
#  'drew',
#  'dothraki',
#  'lay',
#  'realized',
#  'spear',
#  'pushed',
#  'song',
#  'named',
#  'sure',
#  'finally',
#  'whispered',
#  'stand',
#  'reach',
#  'brave',
#  'different',
#  'wolves',
#  'suddenly',
#  'poor',
#  'drogo',
#  'kingsguard',
#  'stay',
#  'arryn',
#  'kingdoms',
#  'stop',
#  'edmure',
#  'broke',
#  'ears',
#  'burning',
#  'princess',
#  'faces',
#  'dream',
#  'lannisters',
#  'axe',
#  'direwolf',
#  'tears',
#  'west',
#  'heir',
#  'clegane',
#  'drink',
#  'darkness',
#  'either',
#  'pointed',
#  'raven',
#  'hill',
#  'try',
#  'forward',
#  'pain',
#  'sworn',
#  'khal',
#  'lie',
#  'dagger',
#  'truly',
#  'kings',
#  'seat',
#  'grown',
#  'born',
#  'road',
#  'harrenhal',
#  'care',
#  'bronn',
#  'round',
#  'helm',
#  'feast',
#  'amongst',
#  'meat',
#  'pycelle',
#  'quick',
#  'understand',
#  'lifted',
#  'longer',
#  'whilst',
#  'reminded',
#  'maybe',
#  'short',
#  'mountain',
#  'step',
#  'rodrik',
#  'melisandre',
#  'ones',
#  'pretty',
#  'third',
#  'bit',
#  'worse',
#  'aegon',
#  'lands',
#  'stopped',
#  'sit',
#  'victarion',
#  'save',
#  'sharp',
#  'knows',
#  'live',
#  'whose',
#  'smoke',
#  'horn',
#  'window',
#  'leg',
#  'pray',
#  'westeros',
#  'younger',
#  'heads',
#  'didn',
#  'silk',
#  'twenty',
#  'ago',
#  'peace',
#  'septa',
#  'pie',
#  'slaves',
#  'hizdahr',
#  'wants',
#  'bread',
#  'low',
#  'laugh',
#  'mind',
#  'blind',
#  'east',
#  'reek',
#  'myself',
#  'mad',
#  'towers',
#  'sooner',
#  'bright',
#  'slain',
#  'coin',
#  'older',
#  'camp',
#  'making',
#  'drowned',
#  'point',
#  'wait',
#  'narrow',
#  'served',
#  'walk',
#  'salt',
#  'glanced',
#  'cousin',
#  'luwin',
#  'cheeks',
#  'knife',
#  'quiet',
#  'riding',
#  'stepped',
#  'touched',
#  'sort',
#  'shook',
#  'targaryen',
#  'often',
#  'twisted',
#  'loras',
#  'naked',
#  'choice',
#  'during',
#  'kevan',
#  'lion',
#  'silence',
#  'fish',
#  'forgotten',
#  'ramsay',
#  'read',
#  'hung',
#  'gift',
#  'running',
#  'replied',
#  'fallen',
#  'large',
#  'knees',
#  'fought',
#  'silent',
#  'cat',
#  'company',
#  'ahead',
#  'sept',
#  'beautiful',
#  'needs',
#  'dogs',
#  'rhaegar',
#  'dawn',
#  'dorne',
#  'casterly',
#  'knee',
#  'pass',
#  'tully',
#  'mud',
#  'themselves',
#  'singer',
#  'gregor',
#  'court',
#  'stupid',
#  'body',
#  'meera',
#  'age',
#  'trying',
#  'top',
#  'swear',
#  'kind',
#  'gendry',
#  'offered',
#  'clothes',
#  'leaves',
#  'whole',
#  'closer',
#  'kiss',
#  'anything',
#  'wonder',
#  'agreed',
#  'threw',
#  'whatever',
#  'pay',
#  'climbed',
#  'answered',
#  'saddle',
#  'wide',
#  'saying',
#  'stars',
#  'comes',
#  'trust',
#  'stones',
#  'host',
#  'chain',
#  'trident',
#  'yourself',
#  'fair',
#  'pleased',
#  'yunkai',
#  'spears',
#  'ear',
#  'eight',
#  'insisted',
#  'hour',
#  'dying',
#  'dry',
#  'fast',
#  'doors',
#  'carried',
#  'service',
#  'ought',
#  'mail',
#  'woods',
#  'council',
#  'fist',
#  'crossed',
#  'wildling',
#  'fine',
#  'wasn',
#  'join',
#  'thank',
#  'milk',
#  'needed',
#  'quentyn',
#  'gilly',
#  'finger',
#  'tent',
#  'doing',
#  'shadows',
#  'helped',
#  'win',
#  'boots',
#  'land',
#  'bird',
#  'folk',
#  'crows',
#  'imp',
#  'somehow',
#  'names',
#  'kissed',
#  'banners',
#  'letter',
#  'winter',
#  'angry',
#  'screamed',
#  'pink',
#  'frightened',
#  'torch',
#  'learn',
#  'alive',
#  'eunuch',
#  'chair',
#  'daughters',
#  'watching',
#  'tarly',
#  'fires',
#  'harm',
#  'dragonstone',
#  'nine',
#  'serving',
#  'neither',
#  'easy',
#  'standing',
#  'learned',
#  'drunk',
#  'question',
#  'wings',
#  'priest',
#  'myrcella',
#  'sail',
#  'sisters',
#  'nodded',
#  'harbor',
#  'forth',
#  'giant',
#  'warned',
#  'bone',
#  'slipped',
#  'slow',
#  'field',
#  'slid',
#  'bronze',
#  'slowly',
#  'falling',
#  'dreams',
#  'promise',
#  'atop',
#  'slave',
#  'illyrio',
#  'move',
#  'line',
#  'whore',
#  'rise',
#  'flowers',
#  'pyke',
#  'makes',
#  'laughter',
#  'grass',
#  'faced',
#  'earth',
#  'loose',
#  'bay',
#  'declared',
#  'front',
#  'twice',
#  'viserys',
#  'lived',
#  'power',
#  'play',
#  'happened',
#  'cell',
#  'because',
#  'chains',
#  'break',
#  'dance',
#  'oldtown',
#  'surely',
#  'clean',
#  'aerys',
#  'jeyne',
#  'eyrie',
#  'unless',
#  'claim',
#  'cried',
#  'fresh',
#  'tormund',
#  'craster',
#  'laid',
#  'pair',
#  'quite',
#  'game',
#  'shouting',
#  'morrow',
#  'met',
#  'sad',
#  'already',
#  'rule',
#  'touch',
#  'softly',
#  'count',
#  'steward',
#  'mounted',
#  'started',
#  'sense',
#  'afterward',
#  'woke',
#  'jojen',
#  'captive',
#  'hide',
#  'sudden',
#  'highgarden',
#  ...]

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=3)

# %%
x=pca.fit_transform(model.wv.get_normed_vectors())

# %%
x[:5]
# Out:
# array([[ 0.1426012 , -0.5873189 ,  0.03691038],
#        [ 0.13143615, -0.3500873 , -0.06117406],
#        [-0.302481  , -0.5601823 , -0.22701147],
#        [-0.00460614, -0.35719836,  0.11688811],
#        [-0.14348815, -0.5223683 , -0.2884564 ]], dtype=float32)

# %%
x.shape##reduced from 100 to 3 dim
# Out:
# (17453, 3)

# %%
import plotly.express as px
fig=px.scatter_3d(x[:500],x=0,y=1,z=2,color=y[:500])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4a1aa862-1f39-4589-a83b-d6853637a7e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a1aa862-1f39-4589-a83b-d6853637a7e7")) {                    Plotly.newPlot(                        "4a1aa862-1f39-4589-a83b-d6853637a7e7",                        [{"hovertemplate":"color=the\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"the","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"the","scene":"scene","showlegend":true,"x":[0.1426012],"y":[-0.5873189],"z":[0.036910385],"type":"scatter3d"},{"hovertemplate":"color=and\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"and","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"and","scene":"scene","showlegend":true,"x":[0.13143615],"y":[-0.3500873],"z":[-0.061174065],"type":"scatter3d"},{"hovertemplate":"color=to\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"to","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"to","scene":"scene","showlegend":true,"x":[-0.302481],"y":[-0.5601823],"z":[-0.22701147],"type":"scatter3d"},{"hovertemplate":"color=of\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"of","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"of","scene":"scene","showlegend":true,"x":[-0.0046061426],"y":[-0.35719836],"z":[0.116888106],"type":"scatter3d"},{"hovertemplate":"color=he\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"he","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"he","scene":"scene","showlegend":true,"x":[-0.14348815],"y":[-0.5223683],"z":[-0.2884564],"type":"scatter3d"},{"hovertemplate":"color=his\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"his","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"his","scene":"scene","showlegend":true,"x":[0.008864254],"y":[-0.29164416],"z":[-0.3346373],"type":"scatter3d"},{"hovertemplate":"color=was\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"was","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"was","scene":"scene","showlegend":true,"x":[-0.14797597],"y":[-0.37959218],"z":[-0.30892062],"type":"scatter3d"},{"hovertemplate":"color=you\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"you","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"you","scene":"scene","showlegend":true,"x":[-0.5662799],"y":[-0.5861539],"z":[-0.16250545],"type":"scatter3d"},{"hovertemplate":"color=her\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"her","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"her","scene":"scene","showlegend":true,"x":[-0.024477229],"y":[-0.38013792],"z":[-0.3760481],"type":"scatter3d"},{"hovertemplate":"color=in\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"in","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"in","scene":"scene","showlegend":true,"x":[0.055740774],"y":[-0.44701105],"z":[-0.09938459],"type":"scatter3d"},{"hovertemplate":"color=it\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fext ...
